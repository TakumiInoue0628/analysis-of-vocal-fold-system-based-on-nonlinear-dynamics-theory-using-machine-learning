# %%
import os
import numpy as np
os.chdir('../../')
from src.data_loading import LoadCSV
from src.visualization.figure import signal
from src.timedelay_embedding import FindTimeDelay

# %%
### Settings

### figure
figure = signal({
        'font.family':'Times New Roman',
        'mathtext.fontset':'stix',
        'font.size':15,
        'xtick.direction':'in',
        'ytick.direction':'in',
        'axes.linewidth':1.5,
        'xtick.major.size':8,
        'ytick.major.size':8,
        }, 
        savefig=False, save_dir='',
        name='', file_type='')

### data loading
CSV_DATA_DIR = './data/vocal_ventricular_flow_rate_change/CSV/'
flow_rate = 40

### spectrogram
stfft_params = {'nperseg': 2000, 'cmap_lim': (-150, 0), 'freq_lim': (0, 300), 'cmap': 'jet'}

# %%
def visualization(data_name, steady_range, serch_size, bins):
    ### Load csv
    [time_all, mic_all, flow_all] = LoadCSV(file_path=CSV_DATA_DIR+data_name+'.csv', 
                                            data_name_list=['T', 'MIC', 'FLOW'], 
                                            sample_span=[0, None])
    flow_all *= flow_rate

    ### Figure
    figure.flow_timeseries_spectrogram(time_all, flow_all, mic_all, stfft_params,
                                title='Sound signal', ylabel=r'[V]',
                                ylim_flow=(None, 170), ylim_signal=(-5, 5),
                                steady_range=steady_range)

    ### Steady range
    time, mic, flow = time_all[steady_range[0]:steady_range[-1]], mic_all[steady_range[0]:steady_range[-1]], flow_all[steady_range[0]:steady_range[-1]]
    time -= time[0]
    print('Flow rate: '+str(np.average(flow)))

    ### Find time-delay
    ftd = FindTimeDelay(mic, search_size=serch_size)
    I = ftd.run(bins=bins, return_I=True)
    tau = ftd.result()

    ### Figure
    figure.timeseries_information_delaycoordinate(time, mic, I, tau, n_plt=2000)
    figure.timeseries_attractor_powerspectra(time, mic, tau, n_plt=1000, 
                                             x_lim=[-4.5, 4.5], f_lim=[0, 200], p_lim=[None, 1.3])

# %%
visualization(data_name='B2_16f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_16f.csv
# data list | T, MIC, FLOW
# Flow rate: 59.96887878417969

# %%
visualization(data_name='B2_19f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_19f.csv
# data list | T, MIC, FLOW
# Flow rate: 79.97877075195312

# %%
visualization(data_name='B2_22f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_22f.csv
# data list | T, MIC, FLOW
# Flow rate: 99.89181030273437

# %%
visualization(data_name='B2_25f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_25f.csv
# data list | T, MIC, FLOW
# Flow rate: 119.84979553222657

# %%
visualization(data_name='B2_28f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_28f.csv
# data list | T, MIC, FLOW
# Flow rate: 139.8972625732422

# %%
visualization(data_name='B2_31f', 
              steady_range=[50000, 60000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/B2_31f.csv
# data list | T, MIC, FLOW
# Flow rate: 159.84670349121095

# %%
visualization(data_name='FVF2_1', 
              steady_range=[60000, 70000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/FVF2_1.csv
# data list | T, MIC, FLOW
# Flow rate: 40.058948364257816

# %%
visualization(data_name='FVF2_4', 
              steady_range=[60000, 70000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/FVF2_4.csv
# data list | T, MIC, FLOW
# Flow rate: 79.9406982421875

# %%
visualization(data_name='FVF3_1', 
              steady_range=[60000, 70000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/FVF3_1.csv
# data list | T, MIC, FLOW
# Flow rate: 40.06189208984375

# %%
visualization(data_name='FVF3_4', 
              steady_range=[60000, 70000], 
              serch_size=500, 
              bins=50, 
              )
# Out:
# Loading csv data
# file path | ./data/vocal_ventricular_flow_rate_change/CSV/FVF3_4.csv
# data list | T, MIC, FLOW
# Flow rate: 79.93968017578125
